# %% [markdown]
# <a href="https://colab.research.google.com/github/mozey256/TGR5/blob/main/ML_Part_1_bioactivity_data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Prediction of Novel Small Molecules as Potential TGR5/GLP1 Agonists in Type 2 Diabetes Treatment  [Part 1] Download Bioactivity Data**
#
# Moses Ainembabazi
#
# [*'mozey256' github account*](https://github.com/mozey256/TGR5)
#
# In this Jupyter notebook, we will be building a real-life **data science project** that you can include in your **data science portfolio**. Particularly, we will be building a machine learning model using the ChEMBL bioactivity data.
#
# ---

# %% [markdown]
# ## **ChEMBL Database**
#
# The [*ChEMBL Database*](https://www.ebi.ac.uk/chembl/) is a database that contains curated bioactivity data of more than 2 million compounds. It is compiled from more than 76,000 documents, 1.2 million assays and the data spans 13,000 targets and 1,800 cells and 33,000 indications.
# [Data as of Febuary 18, 2024; ChEMBL version 27].

# %% [markdown]
# ## **Installing libraries**

# %% [markdown]
# Install the ChEMBL web service package so that we can retrieve bioactivity data from the ChEMBL Database.

# %%
! pip install chembl_webresource_client
# Out:
# Collecting chembl_webresource_client
#   Downloading chembl_webresource_client-0.10.8-py3-none-any.whl (55 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 55.2/55.2 kB 1.2 MB/s eta 0:00:00
# Requirement already satisfied: urllib3 in /usr/local/lib/python3.10/dist-packages (from chembl_webresource_client) (2.0.7)
# Requirement already satisfied: requests>=2.18.4 in /usr/local/lib/python3.10/dist-packages (from chembl_webresource_client) (2.31.0)
# Collecting requests-cache~=0.7.0 (from chembl_webresource_client)
#   Downloading requests_cache-0.7.5-py3-none-any.whl (39 kB)
# Requirement already satisfied: easydict in /usr/local/lib/python3.10/dist-packages (from chembl_webresource_client) (1.12)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.18.4->chembl_webresource_client) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.18.4->chembl_webresource_client) (3.6)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.18.4->chembl_webresource_client) (2024.2.2)
# Collecting attrs<22.0,>=21.2 (from requests-cache~=0.7.0->chembl_webresource_client)
#   Downloading attrs-21.4.0-py2.py3-none-any.whl (60 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.6/60.6 kB 6.3 MB/s eta 0:00:00
# Requirement already satisfied: itsdangerous>=2.0.1 in /usr/local/lib/python3.10/dist-packages (from requests-cache~=0.7.0->chembl_webresource_client) (2.1.2)
# Requirement already satisfied: pyyaml>=5.4 in /usr/local/lib/python3.10/dist-packages (from requests-cache~=0.7.0->chembl_webresource_client) (6.0.1)
# Collecting url-normalize<2.0,>=1.4 (from requests-cache~=0.7.0->chembl_webresource_client)
#   Downloading url_normalize-1.4.3-py2.py3-none-any.whl (6.8 kB)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from url-normalize<2.0,>=1.4->requests-cache~=0.7.0->chembl_webresource_client) (1.16.0)
# Installing collected packages: url-normalize, attrs, requests-cache, chembl_webresource_client
#   Attempting uninstall: attrs
#     Found existing installation: attrs 23.2.0
#     Uninstalling attrs-23.2.0:
#       Successfully uninstalled attrs-23.2.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# lida 0.0.10 requires fastapi, which is not installed.
# lida 0.0.10 requires kaleido, which is not installed.
# lida 0.0.10 requires python-multipart, which is not installed.
# lida 0.0.10 requires uvicorn, which is not installed.
# jsonschema 4.19.2 requires attrs>=22.2.0, but you have attrs 21.4.0 which is incompatible.
# referencing 0.33.0 requires attrs>=22.2.0, but you have attrs 21.4.0 which is incompatible.
# Successfully installed attrs-21.4.0 chembl_webresource_client-0.10.8 requests-cache-0.7.5 url-normalize-1.4.3

# %% [markdown]
# ## **Importing libraries**

# %%
# Import necessary libraries
import pandas as pd
from chembl_webresource_client.new_client import new_client

# %% [markdown]
# ## **Search for Target protein**

# %% [markdown]
# ### **Target search for coronavirus**

# %%
# Target search for tgr5
target = new_client.target
target_query = target.search('tgr5')
targets = pd.DataFrame.from_dict(target_query)
targets
# Out:
#                                     cross_references           organism  \
# 0  [{'xref_id': 'Q80T02', 'xref_name': None, 'xre...  Rattus norvegicus
# 1                                                 []       Mus musculus
# 2  [{'xref_id': 'Q8TDU6', 'xref_name': None, 'xre...       Homo sapiens
#
#                                 pref_name  score  species_group_flag  \
# 0  G-protein coupled bile acid receptor 1   15.0               False
# 1  G-protein coupled bile acid receptor 1   15.0               False
# 2  G-protein coupled bile acid receptor 1   13.0               False
#
#   target_chembl_id                                  target_components  \
# 0    CHEMBL1075223  [{'accession': 'Q80T02', 'component_descriptio...
# 1    CHEMBL1255150  [{'accession': 'Q80SS6', 'component_descriptio...
# 2       CHEMBL5409  [{'accession': 'Q8TDU6', 'component_descriptio...
#
#       target_type  tax_id
# 0  SINGLE PROTEIN   10116
# 1  SINGLE PROTEIN   10090
# 2  SINGLE PROTEIN    9606

# %% [markdown]
# ### **Select and retrieve bioactivity data for *TGR5* (third entry)**

# %% [markdown]
# We will assign the third entry (which corresponds to the target protein, *tgr5*) to the ***selected_target*** variable

# %%
selected_target = targets.target_chembl_id[2]
selected_target
# Out:
# 'CHEMBL5409'

# %% [markdown]
# Here, we will retrieve only bioactivity data for *tgr5* (CHEMBL5409) that are reported as EC$_{50}$ values in nM (nanomolar) unit.

# %%
activity = new_client.activity
res = activity.filter(target_chembl_id=selected_target).filter(standard_type="EC50")

# %%
df = pd.DataFrame.from_dict(res)

# %%
df.head(3)
# Out:
#   action_type activity_comment  activity_id activity_properties  \
# 0        None             None      1918776                  []
# 1        None             None      1918815                  []
# 2        None             None      1918816                  []
#
#   assay_chembl_id                                  assay_description  \
# 0    CHEMBL895768  Agonist activity at human TGR5 expressed in CH...
# 1    CHEMBL895768  Agonist activity at human TGR5 expressed in CH...
# 2    CHEMBL895768  Agonist activity at human TGR5 expressed in CH...
#
#   assay_type assay_variant_accession assay_variant_mutation bao_endpoint  ...  \
# 0          F                    None                   None  BAO_0000188  ...
# 1          F                    None                   None  BAO_0000188  ...
# 2          F                    None                   None  BAO_0000188  ...
#
#   target_organism                        target_pref_name target_tax_id  \
# 0    Homo sapiens  G-protein coupled bile acid receptor 1          9606
# 1    Homo sapiens  G-protein coupled bile acid receptor 1          9606
# 2    Homo sapiens  G-protein coupled bile acid receptor 1          9606
#
#   text_value  toid  type units    uo_units upper_value  value
# 0       None  None  EC50    uM  UO_0000065        None  0.755
# 1       None  None  EC50    uM  UO_0000065        None   51.9
# 2       None  None  EC50    uM  UO_0000065        None   25.5
#
# [3 rows x 46 columns]

# %%
df.standard_type.unique()
# Out:
# array(['EC50'], dtype=object)

# %% [markdown]
# Finally we will save the resulting bioactivity data to a CSV file **bioactivity_data.csv**.

# %%
df.to_csv('bioactivity_data.csv', index=False)

# %% [markdown]
# ## **Copying files to Google Drive**

# %% [markdown]
# Firstly, we need to mount the Google Drive into Colab so that we can have access to our Google adrive from within Colab.

# %%
from google.colab import drive
drive.mount('/content/gdrive/', force_remount=True)
# Out:
# Mounted at /content/gdrive/

# %% [markdown]
# Next, we create a **data** folder in our **Colab Notebooks** folder on Google Drive.

# %%
! mkdir "/content/gdrive/My Drive/Colab Notebooks/data2"
# Out:
# mkdir: cannot create directory ‘/content/gdrive/My Drive/Colab Notebooks/data2’: File exists

# %%
! cp bioactivity_data.csv "/content/gdrive/My Drive/Colab Notebooks/data"

# %%
! ls -l "/content/gdrive/My Drive/Colab Notebooks/data"
# Out:
# -rw------- 1 root root 511463 Feb 20 12:04 '/content/gdrive/My Drive/Colab Notebooks/data'

# %% [markdown]
# Let's see the CSV files that we have so far.

# %%
! ls
# Out:
# bioactivity_data.csv  gdrive  sample_data

# %% [markdown]
# Taking a glimpse of the **bioactivity_data.csv** file that we've just created.

# %%
! head bioactivity_data.csv
# Out:
# action_type,activity_comment,activity_id,activity_properties,assay_chembl_id,assay_description,assay_type,assay_variant_accession,assay_variant_mutation,bao_endpoint,bao_format,bao_label,canonical_smiles,data_validity_comment,data_validity_description,document_chembl_id,document_journal,document_year,ligand_efficiency,molecule_chembl_id,molecule_pref_name,parent_molecule_chembl_id,pchembl_value,potential_duplicate,qudt_units,record_id,relation,src_id,standard_flag,standard_relation,standard_text_value,standard_type,standard_units,standard_upper_value,standard_value,target_chembl_id,target_organism,target_pref_name,target_tax_id,text_value,toid,type,units,uo_units,upper_value,value
# ,,1918776,[],CHEMBL895768,Agonist activity at human TGR5 expressed in CHO cells after 5 hrs by CRE-driven luciferase reporter gene assay,F,,,BAO_0000188,BAO_0000219,cell-based format,CC[C@H]1[C@@H](O)[C@@H]2[C@H](CC[C@]3(C)[C@@H]([C@H](C)CCC(=O)O)CC[C@@H]23)[C@@]2(C)CC[C@@H](O)C[C@@H]12,,,CHEMBL1148757,J Med Chem,2007,,CHEMBL566315,OBETICHOLIC ACID,CHEMBL566315,6.12,0,http://www.openphacts.org/units/Nanomolar,654661,=,1,1,=,,EC50,nM,,755.0,CHEMBL5409,Homo sapiens,G-protein coupled bile acid receptor 1,9606,,,EC50,uM,UO_0000065,,0.755
# ,,1918815,[],CHEMBL895768,Agonist activity at human TGR5 expressed in CHO cells after 5 hrs by CRE-driven luciferase reporter gene assay,F,,,BAO_0000188,BAO_0000219,cell-based format,C[C@H](C[C@@H](C)[C@H]1CC[C@H]2[C@@H]3[C@H](O)CC4C[C@H](O)CC[C@]4(C)[C@H]3C[C@H](O)[C@]12C)C(=O)O,,,CHEMBL1148757,J Med Chem,2007,,CHEMBL388679,,CHEMBL388679,,0,http://www.openphacts.org/units/Nanomolar,654669,>,1,1,>,,EC50,nM,,51900.0,CHEMBL5409,Homo sapiens,G-protein coupled bile acid receptor 1,9606,,,EC50,uM,UO_0000065,,51.9
# ,,1918816,[],CHEMBL895768,Agonist activity at human TGR5 expressed in CHO cells after 5 hrs by CRE-driven luciferase reporter gene assay,F,,,BAO_0000188,BAO_0000219,cell-based format,C[C@H](C[C@@H](C)[C@H]1CC[C@H]2[C@@H]3[C@H](O)CC4C[C@H](O)CC[C@]4(C)[C@H]3CC[C@]12C)C(=O)O,,,CHEMBL1148757,J Med Chem,2007,,CHEMBL245001,,CHEMBL245001,4.59,0,http://www.openphacts.org/units/Nanomolar,654668,=,1,1,=,,EC50,nM,,25500.0,CHEMBL5409,Homo sapiens,G-protein coupled bile acid receptor 1,9606,,,EC50,uM,UO_0000065,,25.5
# ,,1918817,[],CHEMBL895768,Agonist activity at human TGR5 expressed in CHO cells after 5 hrs by CRE-driven luciferase reporter gene assay,F,,,BAO_0000188,BAO_0000219,cell-based format,C[C@H](C[C@H](C)C(=O)O)[C@H]1CC[C@H]2[C@@H]3[C@H](O)CC4C[C@H](O)CC[C@]4(C)[C@H]3C[C@H](O)[C@]12C,,,CHEMBL1148757,J Med Chem,2007,,CHEMBL266356,,CHEMBL266356,5.36,0,http://www.openphacts.org/units/Nanomolar,654667,=,1,1,=,,EC50,nM,,4390.0,CHEMBL5409,Homo sapiens,G-protein coupled bile acid receptor 1,9606,,,EC50,uM,UO_0000065,,4.39
# ,,1918818,[],CHEMBL895768,Agonist activity at human TGR5 expressed in CHO cells after 5 hrs by CRE-driven luciferase reporter gene assay,F,,,BAO_0000188,BAO_0000219,cell-based format,CC[C@@H]1C2C[C@H](O)CC[C@]2(C)[C@H]2CC[C@]3(C)[C@@H]([C@H](C)C[C@H](C)C(=O)O)CC[C@H]3[C@@H]2[C@@H]1O,,,CHEMBL1148757,J Med Chem,2007,,CHEMBL244785,,CHEMBL244785,7.02,0,http://www.openphacts.org/units/Nanomolar,654666,=,1,1,=,,EC50,nM,,95.0,CHEMBL5409,Homo sapiens,G-protein coupled bile acid receptor 1,9606,,,EC50,uM,UO_0000065,,0.095
# ,,1918819,[],CHEMBL895768,Agonist activity at human TGR5 expressed in CHO cells after 5 hrs by CRE-driven luciferase reporter gene assay,F,,,BAO_0000188,BAO_0000219,cell-based format,C[C@H](C[C@H](C)C(=O)O)[C@H]1CC[C@H]2[C@@H]3[C@H](O)[C@H](C)C4C[C@H](O)CC[C@]4(C)[C@H]3CC[C@]12C,,,CHEMBL1148757,J Med Chem,2007,,CHEMBL244784,,CHEMBL244784,6.85,0,http://www.openphacts.org/units/Nanomolar,654665,=,1,1,=,,EC50,nM,,140.0,CHEMBL5409,Homo sapiens,G-protein coupled bile acid receptor 1,9606,,,EC50,uM,UO_0000065,,0.14
# ,,1918820,[],CHEMBL895768,Agonist activity at human TGR5 expressed in CHO cells after 5 hrs by CRE-driven luciferase reporter gene assay,F,,,BAO_0000188,BAO_0000219,cell-based format,C[C@H](C[C@H](C)C(=O)O)[C@H]1CC[C@H]2[C@@H]3[C@H](O)CC4C[C@H](O)CC[C@]4(C)[C@H]3CC[C@]12C,,,CHEMBL1148757,J Med Chem,2007,,CHEMBL244783,,CHEMBL244783,5.45,0,http://www.openphacts.org/units/Nanomolar,654664,=,1,1,=,,EC50,nM,,3580.0,CHEMBL5409,Homo sapiens,G-protein coupled bile acid receptor 1,9606,,,EC50,uM,UO_0000065,,3.58
# ,,1918821,[],CHEMBL895768,Agonist activity at human TGR5 expressed in CHO cells after 5 hrs by CRE-driven luciferase reporter gene assay,F,,,BAO_0000188,BAO_0000219,cell-based format,C[C@H](CCC(=O)O)[C@H]1CC[C@H]2[C@@H]3[C@H](O)C[C@@H]4C[C@H](O)CC[C@]4(C)[C@H]3C[C@H](O)[C@]12C,,,CHEMBL1148757,J Med Chem,2007,,CHEMBL205596,CHOLIC ACID,CHEMBL205596,4.87,1,http://www.openphacts.org/units/Nanomolar,654663,=,1,1,=,,EC50,nM,,13600.0,CHEMBL5409,Homo sapiens,G-protein coupled bile acid receptor 1,9606,,,EC50,uM,UO_0000065,,13.6
# ,,1918822,[],CHEMBL895768,Agonist activity at human TGR5 expressed in CHO cells after 5 hrs by CRE-driven luciferase reporter gene assay,F,,,BAO_0000188,BAO_0000219,cell-based format,C[C@H](CCC(=O)O)[C@H]1CC[C@H]2[C@@H]3[C@H](O)C[C@@H]4C[C@H](O)CC[C@]4(C)[C@H]3CC[C@]12C,,,CHEMBL1148757,J Med Chem,2007,,CHEMBL240597,CHENODIOL,CHEMBL240597,5.17,1,http://www.openphacts.org/units/Nanomolar,654662,=,1,1,=,,EC50,nM,,6710.0,CHEMBL5409,Homo sapiens,G-protein coupled bile acid receptor 1,9606,,,EC50,uM,UO_0000065,,6.71

# %% [markdown]
# ## **Handling missing data**
# If any compounds has missing value for the **standard_value** column then drop it

# %%
df2 = df[df.standard_value.notna()]
df2
# Out:
#                                            action_type activity_comment  \
# 0                                                 None             None
# 1                                                 None             None
# 2                                                 None             None
# 3                                                 None             None
# 4                                                 None             None
# ..                                                 ...              ...
# 913  {'action_type': 'AGONIST', 'description': 'Bin...             None
# 914  {'action_type': 'AGONIST', 'description': 'Bin...             None
# 915  {'action_type': 'AGONIST', 'description': 'Bin...             None
# 916  {'action_type': 'AGONIST', 'description': 'Bin...             None
# 917                                               None             None
#
#      activity_id                                activity_properties  \
# 0        1918776                                                 []
# 1        1918815                                                 []
# 2        1918816                                                 []
# 3        1918817                                                 []
# 4        1918818                                                 []
# ..           ...                                                ...
# 913     24792970  [{'comments': None, 'relation': '=', 'result_f...
# 914     24792971  [{'comments': None, 'relation': '=', 'result_f...
# 915     24792972  [{'comments': None, 'relation': '=', 'result_f...
# 916     24792973  [{'comments': None, 'relation': '=', 'result_f...
# 917     24886259                                                 []
#
#     assay_chembl_id                                  assay_description  \
# 0      CHEMBL895768  Agonist activity at human TGR5 expressed in CH...
# 1      CHEMBL895768  Agonist activity at human TGR5 expressed in CH...
# 2      CHEMBL895768  Agonist activity at human TGR5 expressed in CH...
# 3      CHEMBL895768  Agonist activity at human TGR5 expressed in CH...
# 4      CHEMBL895768  Agonist activity at human TGR5 expressed in CH...
# ..              ...                                                ...
# 913   CHEMBL5133049  Agonist activity against human GPBAR1 expresse...
# 914   CHEMBL5133049  Agonist activity against human GPBAR1 expresse...
# 915   CHEMBL5133049  Agonist activity against human GPBAR1 expresse...
# 916   CHEMBL5133049  Agonist activity against human GPBAR1 expresse...
# 917   CHEMBL5157327  Agonist activity in human GPBAR1 assessed as i...
#
#     assay_type assay_variant_accession assay_variant_mutation bao_endpoint  \
# 0            F                    None                   None  BAO_0000188
# 1            F                    None                   None  BAO_0000188
# 2            F                    None                   None  BAO_0000188
# 3            F                    None                   None  BAO_0000188
# 4            F                    None                   None  BAO_0000188
# ..         ...                     ...                    ...          ...
# 913          F                    None                   None  BAO_0000188
# 914          F                    None                   None  BAO_0000188
# 915          F                    None                   None  BAO_0000188
# 916          F                    None                   None  BAO_0000188
# 917          F                    None                   None  BAO_0000188
#
#      ... target_organism                        target_pref_name  \
# 0    ...    Homo sapiens  G-protein coupled bile acid receptor 1
# 1    ...    Homo sapiens  G-protein coupled bile acid receptor 1
# 2    ...    Homo sapiens  G-protein coupled bile acid receptor 1
# 3    ...    Homo sapiens  G-protein coupled bile acid receptor 1
# 4    ...    Homo sapiens  G-protein coupled bile acid receptor 1
# ..   ...             ...                                     ...
# 913  ...    Homo sapiens  G-protein coupled bile acid receptor 1
# 914  ...    Homo sapiens  G-protein coupled bile acid receptor 1
# 915  ...    Homo sapiens  G-protein coupled bile acid receptor 1
# 916  ...    Homo sapiens  G-protein coupled bile acid receptor 1
# 917  ...    Homo sapiens  G-protein coupled bile acid receptor 1
#
#     target_tax_id text_value  toid  type units    uo_units upper_value  value
# 0            9606       None  None  EC50    uM  UO_0000065        None  0.755
# 1            9606       None  None  EC50    uM  UO_0000065        None   51.9
# 2            9606       None  None  EC50    uM  UO_0000065        None   25.5
# 3            9606       None  None  EC50    uM  UO_0000065        None   4.39
# 4            9606       None  None  EC50    uM  UO_0000065        None  0.095
# ..            ...        ...   ...   ...   ...         ...         ...    ...
# 913          9606       None  None  EC50    uM  UO_0000065        None    0.1
# 914          9606       None  None  EC50    uM  UO_0000065        None    0.5
# 915          9606       None  None  EC50    uM  UO_0000065        None   0.17
# 916          9606       None  None  EC50    uM  UO_0000065        None    1.8
# 917          9606       None  None  EC50    uM  UO_0000065        None   10.0
#
# [909 rows x 46 columns]

# %% [markdown]
# ## **Data pre-processing of the bioactivity data**

# %% [markdown]
# ### **Labeling compounds as either being active, inactive or intermediate**
# The bioactivity data is in the EC50 unit. Compounds having values of less than 1000 nM will be considered to be **active** while those greater than 10,000 nM will be considered to be **inactive**. As for those values in between 1,000 and 10,000 nM will be referred to as **intermediate**.

# %%
bioactivity_class = []
for i in df2.standard_value:
  if float(i) >= 10000:
    bioactivity_class.append("inactive")
  elif float(i) <= 1000:
    bioactivity_class.append("active")
  else:
    bioactivity_class.append("intermediate")

# %% [markdown]
# ### **Iterate the *molecule_chembl_id* to a list**

# %%
mol_cid = []
for i in df2.molecule_chembl_id:
  mol_cid.append(i)

# %% [markdown]
# ### **Iterate *canonical_smiles* to a list**

# %%
canonical_smiles = []
for i in df2.canonical_smiles:
  canonical_smiles.append(i)

# %% [markdown]
# ### **Iterate *standard_value* to a list**

# %%
standard_value = []
for i in df2.standard_value:
  standard_value.append(i)

# %% [markdown]
# ### **Combine the 4 lists into a dataframe**

# %%
data_tuples = list(zip(mol_cid, canonical_smiles, bioactivity_class, standard_value))
df3 = pd.DataFrame( data_tuples,  columns=['molecule_chembl_id', 'canonical_smiles', 'bioactivity_class', 'standard_value'])

# %%
df3
# Out:
#     molecule_chembl_id                                   canonical_smiles  \
# 0         CHEMBL566315  CC[C@H]1[C@@H](O)[C@@H]2[C@H](CC[C@]3(C)[C@@H]...
# 1         CHEMBL388679  C[C@H](C[C@@H](C)[C@H]1CC[C@H]2[C@@H]3[C@H](O)...
# 2         CHEMBL245001  C[C@H](C[C@@H](C)[C@H]1CC[C@H]2[C@@H]3[C@H](O)...
# 3         CHEMBL266356  C[C@H](C[C@H](C)C(=O)O)[C@H]1CC[C@H]2[C@@H]3[C...
# 4         CHEMBL244785  CC[C@@H]1C2C[C@H](O)CC[C@]2(C)[C@H]2CC[C@]3(C)...
# ..                 ...                                                ...
# 904      CHEMBL5192002                  CCC(C)Oc1cccc(OCc2ccc3ccccc3n2)c1
# 905        CHEMBL18775                    CCCCOc1cccc(OCc2ccc3ccccc3n2)c1
# 906      CHEMBL5173976                 CCC(C)COc1cccc(OCc2ccc3ccccc3n2)c1
# 907      CHEMBL5172427                   CCCCCOc1cccc(OCc2ccc3ccccc3n2)c1
# 908      CHEMBL5171962  O=C(O)c1ccc2c(c1)Oc1ccc(OCc3c(-c4c(Cl)cccc4Cl)...
#
#     bioactivity_class standard_value
# 0              active          755.0
# 1            inactive        51900.0
# 2            inactive        25500.0
# 3        intermediate         4390.0
# 4              active           95.0
# ..                ...            ...
# 904            active          100.0
# 905            active          500.0
# 906            active          170.0
# 907      intermediate         1800.0
# 908          inactive        10000.0
#
# [909 rows x 4 columns]

# %% [markdown]
# ### **Alternative method**

# %%
selection = ['molecule_chembl_id', 'canonical_smiles', 'standard_value']
df3 = df2[selection]
df3
# Out:
#     molecule_chembl_id                                   canonical_smiles  \
# 0         CHEMBL566315  CC[C@H]1[C@@H](O)[C@@H]2[C@H](CC[C@]3(C)[C@@H]...
# 1         CHEMBL388679  C[C@H](C[C@@H](C)[C@H]1CC[C@H]2[C@@H]3[C@H](O)...
# 2         CHEMBL245001  C[C@H](C[C@@H](C)[C@H]1CC[C@H]2[C@@H]3[C@H](O)...
# 3         CHEMBL266356  C[C@H](C[C@H](C)C(=O)O)[C@H]1CC[C@H]2[C@@H]3[C...
# 4         CHEMBL244785  CC[C@@H]1C2C[C@H](O)CC[C@]2(C)[C@H]2CC[C@]3(C)...
# ..                 ...                                                ...
# 913      CHEMBL5192002                  CCC(C)Oc1cccc(OCc2ccc3ccccc3n2)c1
# 914        CHEMBL18775                    CCCCOc1cccc(OCc2ccc3ccccc3n2)c1
# 915      CHEMBL5173976                 CCC(C)COc1cccc(OCc2ccc3ccccc3n2)c1
# 916      CHEMBL5172427                   CCCCCOc1cccc(OCc2ccc3ccccc3n2)c1
# 917      CHEMBL5171962  O=C(O)c1ccc2c(c1)Oc1ccc(OCc3c(-c4c(Cl)cccc4Cl)...
#
#     standard_value
# 0            755.0
# 1          51900.0
# 2          25500.0
# 3           4390.0
# 4             95.0
# ..             ...
# 913          100.0
# 914          500.0
# 915          170.0
# 916         1800.0
# 917        10000.0
#
# [909 rows x 3 columns]

# %%
pd.concat([df3,pd.Series(bioactivity_class)], axis=1)
# Out:
#     molecule_chembl_id                                   canonical_smiles  \
# 0         CHEMBL566315  CC[C@H]1[C@@H](O)[C@@H]2[C@H](CC[C@]3(C)[C@@H]...
# 1         CHEMBL388679  C[C@H](C[C@@H](C)[C@H]1CC[C@H]2[C@@H]3[C@H](O)...
# 2         CHEMBL245001  C[C@H](C[C@@H](C)[C@H]1CC[C@H]2[C@@H]3[C@H](O)...
# 3         CHEMBL266356  C[C@H](C[C@H](C)C(=O)O)[C@H]1CC[C@H]2[C@@H]3[C...
# 4         CHEMBL244785  CC[C@@H]1C2C[C@H](O)CC[C@]2(C)[C@H]2CC[C@]3(C)...
# ..                 ...                                                ...
# 686                NaN                                                NaN
# 902                NaN                                                NaN
# 903                NaN                                                NaN
# 905                NaN                                                NaN
# 908                NaN                                                NaN
#
#     standard_value             0
# 0            755.0        active
# 1          51900.0      inactive
# 2          25500.0      inactive
# 3           4390.0  intermediate
# 4             95.0        active
# ..             ...           ...
# 686            NaN        active
# 902            NaN      inactive
# 903            NaN        active
# 905            NaN        active
# 908            NaN      inactive
#
# [917 rows x 4 columns]

# %% [markdown]
# Saves dataframe to CSV file

# %%
df3.to_csv('bioactivity_preprocessed_data.csv', index=False)

# %%
! ls -l
# Out:
# total 592
# -rw-r--r-- 1 root root 511463 Feb 20 12:03 bioactivity_data.csv
# -rw-r--r-- 1 root root  82665 Feb 20 12:04 bioactivity_preprocessed_data.csv
# drwx------ 6 root root   4096 Feb 20 12:04 gdrive
# drwxr-xr-x 1 root root   4096 Feb 14 14:28 sample_data

# %% [markdown]
# Let's copy to the Google Drive

# %%
! cp bioactivity_preprocessed_data.csv "/content/gdrive/My Drive/Colab Notebooks/data"

# %%
! ls "/content/gdrive/My Drive/Colab Notebooks/data"
# Out:
# '/content/gdrive/My Drive/Colab Notebooks/data'

# %% [markdown]
# ---
